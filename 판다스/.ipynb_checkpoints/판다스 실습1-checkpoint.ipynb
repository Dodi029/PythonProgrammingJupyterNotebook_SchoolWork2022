# %%
import os
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('/Users/doyoung/학교/Python_Programming_JupyterNotebook/데이터/Life_expectancy.csv', sep=',')

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (2938, 22)

# %%
type(dataset) #->데이터 프레임 속성 또는 함수들을 이용할 수 있다.
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.ndim
# Out:
# 2

# %%
dataset.shape
# Out:
# (2938, 22)

# %%
dataset.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult mortality',
#        'Infant deaths', 'Alcohol', 'Percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'Under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', 'HIV/AIDS', 'GDP', 'Population', 'Thinness 1-19 years',
#        'Thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
dataset.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria   HIV/AIDS         GDP  Population  \
# ...

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=2938, step=1)

# %%
dataset.head(100)
# Out:
#         Country  Year      Status  Life expectancy  Adult mortality  \
# 0   Afghanistan  2015  Developing             65.0            263.0
# 1   Afghanistan  2014  Developing             59.9            271.0
# 2   Afghanistan  2013  Developing             59.9            268.0
# 3   Afghanistan  2012  Developing             59.5            272.0
# 4   Afghanistan  2011  Developing             59.2            275.0
# ..          ...   ...         ...              ...              ...
# 95    Argentina  2000  Developing             74.1            137.0
# 96      Armenia  2015  Developing             74.8            118.0
# 97      Armenia  2014  Developing             74.6             12.0
# 98      Armenia  2013  Developing             74.4            123.0
# 99      Armenia  2012  Developing             74.4            121.0
#
#     Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# ...

# %%
dataset.tail(100)
# Out:
#          Country  Year      Status  Life expectancy  Adult mortality  \
# 2838  Uzbekistan  2003  Developing             67.2            183.0
# 2839  Uzbekistan  2002  Developing             67.1            186.0
# 2840  Uzbekistan  2001  Developing             67.4            185.0
# 2841  Uzbekistan  2000  Developing             67.1            189.0
# 2842     Vanuatu  2015  Developing             72.0             13.0
# ...          ...   ...         ...              ...              ...
# 2933    Zimbabwe  2004  Developing             44.3            723.0
# 2934    Zimbabwe  2003  Developing             44.5            715.0
# 2935    Zimbabwe  2002  Developing             44.8             73.0
# 2936    Zimbabwe  2001  Developing             45.3            686.0
# 2937    Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
dataset['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
dataset.describe()
# Out:
#               Year  Life expectancy  Adult mortality  Infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  Percentage expenditure  Hepatitis B        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
dataset['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
np.unique(dataset['Status'],return_counts=True)
# Out:
# (array(['Developed', 'Developing'], dtype=object), array([ 512, 2426]))

# %%
dataset['Infant deaths'].hist()
# Out:
# <AxesSubplot:>

# %%
dataset['Life expectancy'].hist()
# Out:
# <AxesSubplot:>

# %%
dataset['Life expectancy'].hist(bins=30, figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %%
dataset['Infant deaths'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
dataset['Life expectancy'].hist(bins=100, figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=2938, step=1)

# %%
subdata_1 = dataset.loc[0:100]
print(subdata_1.shape)
subdata_1.head()
# Out:
# (101, 22)
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria   HIV/AIDS         GDP  Population  \
# ...

# %%
subdata_1 = dataset.iloc[25:100]
print(subdata_1.shape)
subdata_1.head()
# Out:
# (75, 22)
#     Country  Year      Status  Life expectancy  Adult mortality  \
# 25  Albania  2006  Developing             74.2             99.0
# 26  Albania  2005  Developing             73.5             15.0
# 27  Albania  2004  Developing             73.0             17.0
# 28  Albania  2003  Developing             72.8             18.0
# 29  Albania  2002  Developing             73.3             15.0
#
#     Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 25              1     5.31                3.302154         98.0       68  ...
# 26              1     5.16               26.993121         98.0        6  ...
# 27              1     4.54              221.842800         99.0        7  ...
# 28              1     4.29               14.719289         97.0        8  ...
# 29              1     3.73              104.516916         96.0       16  ...
#
#     Polio  Total expenditure  Diphtheria   HIV/AIDS          GDP  Population  \
# ...

# %%
subdata_1 = dataset.iloc[25:100, :10]
print(subdata_1.shape)
subdata_1.head()
# Out:
# (75, 10)
#     Country  Year      Status  Life expectancy  Adult mortality  \
# 25  Albania  2006  Developing             74.2             99.0
# 26  Albania  2005  Developing             73.5             15.0
# 27  Albania  2004  Developing             73.0             17.0
# 28  Albania  2003  Developing             72.8             18.0
# 29  Albania  2002  Developing             73.3             15.0
#
#     Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles
# 25              1     5.31                3.302154         98.0       68
# 26              1     5.16               26.993121         98.0        6
# 27              1     4.54              221.842800         99.0        7
# 28              1     4.29               14.719289         97.0        8
# 29              1     3.73              104.516916         96.0       16

# %%
indices = np.array(dataset.index)

# %%
condition1 = dataset['Population'] >= (10 * 1000 * 1000)

# %%
condition1
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2933     True
# 2934     True
# 2935    False
# 2936     True
# 2937     True
# Name: Population, Length: 2938, dtype: bool

# %%
condition2 = dataset['Life expectancy'] <= 60

# %%
condition2
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2933     True
# 2934     True
# 2935     True
# 2936     True
# 2937     True
# Name: Life expectancy, Length: 2938, dtype: bool

# %%
indices[condition1 & condition2]
# Out:
# array([   2,    8,   11,   13,   52,   53,   54,   58,   59,   61,   62,
#         401,  403,  407,  409,  412,  414,  477,  479,  480,  482,  486,
#         488,  489,  492,  494,  495,  529,  530,  532,  535,  889,  894,
#         896,  897, 1019, 1023, 1025, 1076, 1077, 1369, 1376, 1566, 1567,
#        1572, 1574, 1577, 1579, 1582, 1584, 1585, 1619, 1620, 1625, 1628,
#        1631, 1632, 1765, 1766, 1771, 1772, 1773, 1776, 1777, 1778, 1787,
#        1882, 1883, 1884, 1885, 1887, 1891, 1892, 1893, 1895, 1896, 1897,
#        1898, 1899, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 2397, 2400,
#        2401, 2405, 2406, 2407, 2408, 2409, 2469, 2470, 2719, 2720, 2721,
#        2725, 2728, 2909, 2910, 2912, 2914, 2915, 2917, 2918, 2923, 2926,
#        2929, 2931, 2933, 2934, 2936, 2937])

# %%
indice1 = indices[condition1 & condition2]

# %%
dataset.loc[indice1]
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 2     Afghanistan  2013  Developing             59.9            268.0
# 8     Afghanistan  2007  Developing             57.5            295.0
# 11    Afghanistan  2004  Developing             57.0            293.0
# 13    Afghanistan  2002  Developing             56.2              3.0
# 52         Angola  2011  Developing             51.0            361.0
# ...           ...   ...         ...              ...              ...
# 2931     Zimbabwe  2006  Developing             45.4              7.0
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
dataset[condition1 & condition2]
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 2     Afghanistan  2013  Developing             59.9            268.0
# 8     Afghanistan  2007  Developing             57.5            295.0
# 11    Afghanistan  2004  Developing             57.0            293.0
# 13    Afghanistan  2002  Developing             56.2              3.0
# 52         Angola  2011  Developing             51.0            361.0
# ...           ...   ...         ...              ...              ...
# 2931     Zimbabwe  2006  Developing             45.4              7.0
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
dataset.iloc[indice1, :]
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 2     Afghanistan  2013  Developing             59.9            268.0
# 8     Afghanistan  2007  Developing             57.5            295.0
# 11    Afghanistan  2004  Developing             57.0            293.0
# 13    Afghanistan  2002  Developing             56.2              3.0
# 52         Angola  2011  Developing             51.0            361.0
# ...           ...   ...         ...              ...              ...
# 2931     Zimbabwe  2006  Developing             45.4              7.0
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
dataset.shape
# Out:
# (2938, 22)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult mortality                  2928 non-null   float64
#  5   Infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   Percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  Under-five deaths                2938 non-null   int64
# ...

# %%
dataset.isna()
# Out:
#       Country   Year  Status  Life expectancy  Adult mortality  Infant deaths  \
# 0       False  False   False            False            False          False
# 1       False  False   False            False            False          False
# 2       False  False   False            False            False          False
# 3       False  False   False            False            False          False
# 4       False  False   False            False            False          False
# ...       ...    ...     ...              ...              ...            ...
# 2933    False  False   False            False            False          False
# 2934    False  False   False            False            False          False
# 2935    False  False   False            False            False          False
# 2936    False  False   False            False            False          False
# 2937    False  False   False            False            False          False
#
# ...

# %%
dataset.isnull()
# Out:
#       Country   Year  Status  Life expectancy  Adult mortality  Infant deaths  \
# 0       False  False   False            False            False          False
# 1       False  False   False            False            False          False
# 2       False  False   False            False            False          False
# 3       False  False   False            False            False          False
# 4       False  False   False            False            False          False
# ...       ...    ...     ...              ...              ...            ...
# 2933    False  False   False            False            False          False
# 2934    False  False   False            False            False          False
# 2935    False  False   False            False            False          False
# 2936    False  False   False            False            False          False
# 2937    False  False   False            False            False          False
#
# ...

# %%
dataset.isnull().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2933    0
# 2934    0
# 2935    0
# 2936    0
# 2937    0
# Length: 2938, dtype: int64

# %%
dataset.shape
# Out:
# (2938, 22)

# %%
dataset.dropna(axis=1, how='any').shape
# Out:
# (2938, 8)

# %%
dataset.dropna(axis=1, how='any').shape #많은 데이터 손실
# Out:
# (2938, 8)

# %%
indices[dataset.isnull().any(axis=1)]
# Out:
# array([  32,   44,   45, ..., 2920, 2921, 2922])

# %%
null_indices = indices[dataset.isnull().any(axis=1)]

# %%
dataset.loc[null_indices]
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 32     Algeria  2015  Developing             75.6             19.0
# 44     Algeria  2003  Developing             71.7            146.0
# 45     Algeria  2002  Developing             71.6            145.0
# 46     Algeria  2001  Developing             71.4            145.0
# 47     Algeria  2000  Developing             71.3            145.0
# ...        ...   ...         ...              ...              ...
# 2918    Zambia  2003  Developing             46.4             64.0
# 2919    Zambia  2002  Developing             45.5             69.0
# 2920    Zambia  2001  Developing             44.6            611.0
# 2921    Zambia  2000  Developing             43.8            614.0
# 2922  Zimbabwe  2015  Developing             67.0            336.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 32               21      NaN                0.000000         95.0       63
# ...

# %%
dataset.isnull().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2933    False
# 2934    False
# 2935    False
# 2936    False
# 2937    False
# Length: 2938, dtype: bool

# %%
indices = np.array(dataset.index)

# %%
indices
# Out:
# array([   0,    1,    2, ..., 2935, 2936, 2937])

# %%
dataset.isnull()
# Out:
#       Country   Year  Status  Life expectancy  Adult mortality  Infant deaths  \
# 0       False  False   False            False            False          False
# 1       False  False   False            False            False          False
# 2       False  False   False            False            False          False
# 3       False  False   False            False            False          False
# 4       False  False   False            False            False          False
# ...       ...    ...     ...              ...              ...            ...
# 2933    False  False   False            False            False          False
# 2934    False  False   False            False            False          False
# 2935    False  False   False            False            False          False
# 2936    False  False   False            False            False          False
# 2937    False  False   False            False            False          False
#
# ...

# %%
dataset.isnull().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2933    False
# 2934    False
# 2935    False
# 2936    False
# 2937    False
# Length: 2938, dtype: bool

# %%
indices[dataset.isnull().any(axis=1)]
# Out:
# array([  32,   44,   45, ..., 2920, 2921, 2922])

# %%
null_indices = indices[dataset.isnull().any(axis=1)]

# %%
dataset.loc[null_indices]
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 32     Algeria  2015  Developing             75.6             19.0
# 44     Algeria  2003  Developing             71.7            146.0
# 45     Algeria  2002  Developing             71.6            145.0
# 46     Algeria  2001  Developing             71.4            145.0
# 47     Algeria  2000  Developing             71.3            145.0
# ...        ...   ...         ...              ...              ...
# 2918    Zambia  2003  Developing             46.4             64.0
# 2919    Zambia  2002  Developing             45.5             69.0
# 2920    Zambia  2001  Developing             44.6            611.0
# 2921    Zambia  2000  Developing             43.8            614.0
# 2922  Zimbabwe  2015  Developing             67.0            336.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 32               21      NaN                0.000000         95.0       63
# ...

# %%
dataset.loc[null_indices]
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 32     Algeria  2015  Developing             75.6             19.0
# 44     Algeria  2003  Developing             71.7            146.0
# 45     Algeria  2002  Developing             71.6            145.0
# 46     Algeria  2001  Developing             71.4            145.0
# 47     Algeria  2000  Developing             71.3            145.0
# ...        ...   ...         ...              ...              ...
# 2918    Zambia  2003  Developing             46.4             64.0
# 2919    Zambia  2002  Developing             45.5             69.0
# 2920    Zambia  2001  Developing             44.6            611.0
# 2921    Zambia  2000  Developing             43.8            614.0
# 2922  Zimbabwe  2015  Developing             67.0            336.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 32               21      NaN                0.000000         95.0       63
# ...

# %%
missing_dataset = dataset.loc[null_indices]

# %%
missing_dataset.isna().sum(axis=1)
# Out:
# 32      2
# 44      1
# 45      1
# 46      1
# 47      1
#        ..
# 2918    1
# 2919    1
# 2920    1
# 2921    1
# 2922    2
# Length: 1289, dtype: int64

# %%
dataset.loc[null_indices].isna().sum(axis=1).mean()
# Out:
# 1.9883630721489527

# %%
"missing value 있는 관측치는 평균적으로 2개 정도 missing value 포함하고 있다"
